# %%
import tensorflow as tf
from tensorflow.keras import layers
print(tf.__version__)
print(tf.keras.__version__)
# Out:
# 2.0.0
# 2.2.4-tf

# %%
model = tf.keras.Sequential()
model.add(layers.Dense(32, activation='relu'))
model.add(layers.Dense(32, activation='relu'))
model.add(layers.Dense(10, activation='softmax'))

# %%
model.compile(optimizer=tf.optimizers.Adam(0.001),
             loss=tf.keras.losses.categorical_crossentropy,
             metrics=[tf.keras.metrics.categorical_accuracy])

# %%
import numpy as np

train_x = np.random.random((1000, 72))
train_y = np.random.random((1000, 10))

val_x = np.random.random((200, 72))
val_y = np.random.random((200, 10))

model.fit(train_x, train_y, epochs=10, batch_size=128,
          validation_data=(val_x, val_y))
# Out:
# Train on 1000 samples, validate on 200 samples
# Epoch 1/10
# 1000/1000 [==============================] - 1s 592us/sample - loss: 11.7263 - categorical_accuracy: 0.0990 - val_loss: 11.5231 - val_categorical_accuracy: 0.0950
# Epoch 2/10
# 1000/1000 [==============================] - 0s 22us/sample - loss: 11.7517 - categorical_accuracy: 0.1010 - val_loss: 11.6595 - val_categorical_accuracy: 0.1050
# Epoch 3/10
# 1000/1000 [==============================] - 0s 21us/sample - loss: 11.9894 - categorical_accuracy: 0.1000 - val_loss: 12.0407 - val_categorical_accuracy: 0.0950
# Epoch 4/10
# 1000/1000 [==============================] - 0s 22us/sample - loss: 12.5535 - categorical_accuracy: 0.1060 - val_loss: 12.8591 - val_categorical_accuracy: 0.1050
# Epoch 5/10
# 1000/1000 [==============================] - 0s 23us/sample - loss: 13.7111 - categorical_accuracy: 0.1020 - val_loss: 14.4869 - val_categorical_accuracy: 0.0950
# Epoch 6/10
# 1000/1000 [==============================] - 0s 22us/sample - loss: 15.8369 - categorical_accuracy: 0.1020 - val_loss: 16.9768 - val_categorical_accuracy: 0.0950
# Epoch 7/10
# 1000/1000 [==============================] - 0s 20us/sample - loss: 18.2589 - categorical_accuracy: 0.1020 - val_loss: 18.8303 - val_categorical_accuracy: 0.0950
# Epoch 8/10
# 1000/1000 [==============================] - 0s 22us/sample - loss: 19.7730 - categorical_accuracy: 0.1030 - val_loss: 20.0878 - val_categorical_accuracy: 0.0950
# Epoch 9/10
# 1000/1000 [==============================] - 0s 22us/sample - loss: 21.5914 - categorical_accuracy: 0.1030 - val_loss: 22.5239 - val_categorical_accuracy: 0.1050
# Epoch 10/10
# 1000/1000 [==============================] - 0s 22us/sample - loss: 24.4930 - categorical_accuracy: 0.0990 - val_loss: 25.7394 - val_categorical_accuracy: 0.0950

# %%
dataset = tf.data.Dataset.from_tensor_slices((train_x, train_y))
dataset = dataset.batch(32)
dataset = dataset.repeat()
val_dataset = tf.data.Dataset.from_tensor_slices((val_x, val_y))
val_dataset = val_dataset.batch(32)
val_dataset = val_dataset.repeat()

model.fit(dataset, epochs=10, steps_per_epoch=30,
          validation_data=val_dataset, validation_steps=3)
# Out:
# Train for 30 steps, validate for 3 steps
# Epoch 1/10
# 30/30 [==============================] - 0s 2ms/step - loss: 35.2815 - categorical_accuracy: 0.1052 - val_loss: 45.7398 - val_categorical_accuracy: 0.1146
# Epoch 2/10
# 30/30 [==============================] - 0s 1ms/step - loss: 60.2669 - categorical_accuracy: 0.1058 - val_loss: 75.3564 - val_categorical_accuracy: 0.1146
# Epoch 3/10
# 30/30 [==============================] - 0s 1ms/step - loss: 95.8527 - categorical_accuracy: 0.1058 - val_loss: 113.8492 - val_categorical_accuracy: 0.1146
# Epoch 4/10
# 30/30 [==============================] - 0s 1ms/step - loss: 141.9596 - categorical_accuracy: 0.1079 - val_loss: 164.2101 - val_categorical_accuracy: 0.1250
# Epoch 5/10
# 30/30 [==============================] - 0s 1ms/step - loss: 201.1370 - categorical_accuracy: 0.1004 - val_loss: 228.5673 - val_categorical_accuracy: 0.1042
# Epoch 6/10
# 30/30 [==============================] - 0s 1ms/step - loss: 274.9172 - categorical_accuracy: 0.0951 - val_loss: 303.3949 - val_categorical_accuracy: 0.0833
# Epoch 7/10
# 30/30 [==============================] - 0s 1ms/step - loss: 354.8451 - categorical_accuracy: 0.0962 - val_loss: 382.4808 - val_categorical_accuracy: 0.0833
# Epoch 8/10
# 30/30 [==============================] - 0s 1ms/step - loss: 438.9372 - categorical_accuracy: 0.0929 - val_loss: 463.7048 - val_categorical_accuracy: 0.1250
# Epoch 9/10
# 30/30 [==============================] - 0s 2ms/step - loss: 525.6843 - categorical_accuracy: 0.0887 - val_loss: 547.8161 - val_categorical_accuracy: 0.1042
# Epoch 10/10
# 30/30 [==============================] - 0s 1ms/step - loss: 626.3167 - categorical_accuracy: 0.0983 - val_loss: 649.1909 - val_categorical_accuracy: 0.0938

# %%
test_x = np.random.random((1000, 72))
test_y = np.random.random((1000, 10))
model.evaluate(test_x, test_y, batch_size=32)

test_data = tf.data.Dataset.from_tensor_slices((test_x, test_y))
test_data = test_data.batch(32).repeat()
model.evaluate(test_data, steps=30)

# predict
result = model.predict(test_x, batch_size=32)
print(result)
# Out:
# 1000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================== ...
# 30/30 [==============================] - 0s 904us/step - loss: 665.9582 - categorical_accuracy: 0.1198
# [[0.16994993 0.2188603  0.2275787  ... 0.01569245 0.2027094  0.        ]
#  [0.14397407 0.1826234  0.36336738 ... 0.01231292 0.18722826 0.        ]
#  [0.13215557 0.16503337 0.3601142  ... 0.01043241 0.19579068 0.        ]
#  ...
#  [0.13063355 0.12816942 0.33391035 ... 0.01075451 0.20521457 0.        ]
#  [0.12352926 0.2360253  0.3094929  ... 0.01410538 0.20396389 0.        ]
#  [0.2164688  0.11902123 0.22041515 ... 0.00667223 0.21290474 0.        ]]

# %% [markdown]
# ### 高级模型

# %%
input_x = tf.keras.Input(shape=(72,))
hidden1 = layers.Dense(32, activation='relu')(input_x)
hidden2 = layers.Dense(16, activation='relu')(hidden1)
pred = layers.Dense(10, activation='softmax')(hidden2)

model = tf.keras.Model(inputs=input_x, outputs=pred)
model.compile(optimizer=tf.keras.optimizers.Adam(0.001),
             loss=tf.keras.losses.categorical_crossentropy,
             metrics=['accuracy'])
model.fit(train_x, train_y, batch_size=32, epochs=5)
# Out:
# Train on 1000 samples
# Epoch 1/5
# 1000/1000 [==============================] - 0s 381us/sample - loss: 12.4106 - accuracy: 0.0830
# Epoch 2/5
# 1000/1000 [==============================] - 0s 44us/sample - loss: 18.4104 - accuracy: 0.0960
# Epoch 3/5
# 1000/1000 [==============================] - 0s 43us/sample - loss: 34.7654 - accuracy: 0.0990
# Epoch 4/5
# 1000/1000 [==============================] - 0s 49us/sample - loss: 64.2943 - accuracy: 0.0910
# Epoch 5/5
# 1000/1000 [==============================] - 0s 45us/sample - loss: 104.6294 - accuracy: 0.0940

# %%
class MyModel(tf.keras.Model):
    def __init__(self, num_classes=10):
        super(MyModel, self).__init__(name='my_model')
        self.num_classes = num_classes
        self.layer1 = layers.Dense(32, activation='relu')
        self.layer2 = layers.Dense(num_classes, activation='softmax')
    def call(self, inputs):
        h1 = self.layer1(inputs)
        out = self.layer2(h1)
        return out

    def compute_output_shape(self, input_shape):
        shape = tf.TensorShape(input_shape).as_list()
        shape[-1] = self.num_classes
        return tf.TensorShape(shape)

model = MyModel(num_classes=10)
model.compile(optimizer=tf.keras.optimizers.RMSprop(0.001),
             loss=tf.keras.losses.categorical_crossentropy,
             metrics=['accuracy'])

model.fit(train_x, train_y, batch_size=16, epochs=5)
# Out:
# Train on 1000 samples
# Epoch 1/5
# 1000/1000 [==============================] - 0s 379us/sample - loss: 14.7265 - accuracy: 0.1010
# Epoch 2/5
# 1000/1000 [==============================] - 0s 126us/sample - loss: 18.5143 - accuracy: 0.0960
# Epoch 3/5
# 1000/1000 [==============================] - 0s 66us/sample - loss: 22.0945 - accuracy: 0.1010
# Epoch 4/5
# 1000/1000 [==============================] - 0s 65us/sample - loss: 25.6858 - accuracy: 0.1000
# Epoch 5/5
# 1000/1000 [==============================] - 0s 64us/sample - loss: 29.4147 - accuracy: 0.1040

# %%
class MyLayer(layers.Layer):
    def __init__(self, output_dim, **kwargs):
        self.output_dim = output_dim
        super(MyLayer, self).__init__(**kwargs)

    def build(self, input_shape):
        shape = tf.TensorShape((input_shape[1], self.output_dim))
        self.kernel = self.add_weight(name='kernel1', shape=shape,
                                   initializer='uniform', trainable=True)
        super(MyLayer, self).build(input_shape)

    def call(self, inputs):
        return tf.matmul(inputs, self.kernel)

    def compute_output_shape(self, input_shape):
        shape = tf.TensorShape(input_shape).as_list()
        shape[-1] = self.output_dim
        return tf.TensorShape(shape)

    def get_config(self):
        base_config = super(MyLayer, self).get_config()
        base_config['output_dim'] = self.output_dim
        return base_config

    @classmethod
    def from_config(cls, config):
        return cls(**config)

model = tf.keras.Sequential(
[
    MyLayer(10),
    layers.Activation('softmax')
])


model.compile(optimizer=tf.keras.optimizers.RMSprop(0.001),
             loss=tf.keras.losses.categorical_crossentropy,
             metrics=['accuracy'])

model.fit(train_x, train_y, batch_size=16, epochs=5)
# Out:
# Train on 1000 samples
# Epoch 1/5
# 1000/1000 [==============================] - 0s 284us/sample - loss: 11.5791 - accuracy: 0.0950
# Epoch 2/5
# 1000/1000 [==============================] - 0s 58us/sample - loss: 11.5776 - accuracy: 0.0970
# Epoch 3/5
# 1000/1000 [==============================] - 0s 57us/sample - loss: 11.5789 - accuracy: 0.1040
# Epoch 4/5
# 1000/1000 [==============================] - 0s 61us/sample - loss: 11.5778 - accuracy: 0.0950
# Epoch 5/5
# 1000/1000 [==============================] - 0s 56us/sample - loss: 11.5781 - accuracy: 0.0960

# %%
callbacks = [
    tf.keras.callbacks.EarlyStopping(patience=2, monitor='var_loss'),
    tf.keras.callbacks.TensorBoard()
]
model.fit(train_x, train_y, batch_size=16, epochs=5,
         callbacks=callbacks, validation_data=(val_x, val_y))
# Out:
# Train on 1000 samples, validate on 200 samples
# Epoch 1/5
#  752/1000 [=====================>........] - ETA: 0s - loss: 11.5665 - accuracy: 0.1077WARNING:tensorflow:Early stopping conditioned on metric `var_loss` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 1000/1000 [==============================] - 0s 160us/sample - loss: 11.5787 - accuracy: 0.0990 - val_loss: 11.3919 - val_accuracy: 0.1200
# Epoch 2/5
#  848/1000 [========================>.....] - ETA: 0s - loss: 11.5441 - accuracy: 0.1038WARNING:tensorflow:Early stopping conditioned on metric `var_loss` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 1000/1000 [==============================] - 0s 84us/sample - loss: 11.5777 - accuracy: 0.1050 - val_loss: 11.3925 - val_accuracy: 0.1050
# Epoch 3/5
#  896/1000 [=========================>....] - ETA: 0s - loss: 11.5551 - accuracy: 0.1127WARNING:tensorflow:Early stopping conditioned on metric `var_loss` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 1000/1000 [==============================] - 0s 79us/sample - loss: 11.5767 - accuracy: 0.1100 - val_loss: 11.3962 - val_accuracy: 0.1050
# Epoch 4/5
#  832/1000 [=======================>......] - ETA: 0s - loss: 11.5798 - accuracy: 0.1010WARNING:tensorflow:Early stopping conditioned on metric `var_loss` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 1000/1000 [==============================] - 0s 82us/sample - loss: 11.5771 - accuracy: 0.1060 - val_loss: 11.3895 - val_accuracy: 0.1250
# Epoch 5/5
#  848/1000 [========================>.....] - ETA: 0s - loss: 11.5522 - accuracy: 0.1120WARNING:tensorflow:Early stopping conditioned on metric `var_loss` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 1000/1000 [==============================] - 0s 80us/sample - loss: 11.5758 - accuracy: 0.1080 - val_loss: 11.3920 - val_accuracy: 0.1100

# %% [markdown]
# ### 保持和恢复

# %%
model = tf.keras.Sequential([
layers.Dense(64, activation='relu'),
layers.Dense(10, activation='softmax')])

model.compile(optimizer=tf.keras.optimizers.Adam(0.001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])
model.fit(train_x, train_y, batch_size=16, epochs=5, validation_data=(val_x, val_y))

model.save_weights('./weights/my_model')
model.load_weights('./weights/my_model')
model.save_weights('./my_model.h5', save_format='h5')
model.load_weights('./my_model.h5')
# Out:
# Train on 1000 samples, validate on 200 samples
# Epoch 1/5
# 1000/1000 [==============================] - 0s 344us/sample - loss: 14.1187 - accuracy: 0.1030 - val_loss: 17.0609 - val_accuracy: 0.1100
# Epoch 2/5
# 1000/1000 [==============================] - 0s 91us/sample - loss: 20.6382 - accuracy: 0.1060 - val_loss: 24.1539 - val_accuracy: 0.1100
# Epoch 3/5
# 1000/1000 [==============================] - ETA: 0s - loss: 26.9398 - accuracy: 0.108 - 0s 88us/sample - loss: 27.4438 - accuracy: 0.1000 - val_loss: 30.5496 - val_accuracy: 0.1200
# Epoch 4/5
# 1000/1000 [==============================] - 0s 86us/sample - loss: 33.6373 - accuracy: 0.1020 - val_loss: 35.6505 - val_accuracy: 0.1100
# Epoch 5/5
# 1000/1000 [==============================] - 0s 93us/sample - loss: 37.3087 - accuracy: 0.1010 - val_loss: 38.3924 - val_accuracy: 0.1100

# %%
# Create a trivial model
model = tf.keras.Sequential([
  layers.Dense(10, activation='softmax', input_shape=(72,)),
  layers.Dense(10, activation='softmax')
])
model.compile(optimizer='rmsprop',
              loss='categorical_crossentropy',
              metrics=['accuracy'])
model.fit(train_x, train_y, batch_size=16, epochs=5, validation_data=(val_x, val_y))

# Save entire model to a HDF5 file
model.save('my_model.h5')

# Recreate the exact same model, including weights and optimizer.
model = tf.keras.models.load_model('my_model.h5')
# Out:
# Train on 1000 samples, validate on 200 samples
# Epoch 1/5
# 1000/1000 [==============================] - 0s 375us/sample - loss: 11.6275 - accuracy: 0.0950 - val_loss: 11.4570 - val_accuracy: 0.0800
# Epoch 2/5
# 1000/1000 [==============================] - 0s 90us/sample - loss: 11.7053 - accuracy: 0.0960 - val_loss: 11.5141 - val_accuracy: 0.0900
# Epoch 3/5
# 1000/1000 [==============================] - 0s 85us/sample - loss: 11.7551 - accuracy: 0.0960 - val_loss: 11.5346 - val_accuracy: 0.0900
# Epoch 4/5
# 1000/1000 [==============================] - 0s 84us/sample - loss: 11.7682 - accuracy: 0.0960 - val_loss: 11.5372 - val_accuracy: 0.0900
# Epoch 5/5
# 1000/1000 [==============================] - 0s 83us/sample - loss: 11.7693 - accuracy: 0.0960 - val_loss: 11.5374 - val_accuracy: 0.0900
